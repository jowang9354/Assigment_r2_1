# %%
import azure.cognitiveservices.speech as speechsdk
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Set up the subscription info for the Speech Service:

# %%
speech_key, service_region = os.getenv('SPEECH_SERVICE_KEY'), "EastUS"

# %% [markdown]
# Create an instance of a speech config with specified subscription key and service region.
# Replace with your own subscription key and service region (e.g., "westus").

# %%
speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)

# %% [markdown]
# Create a recognizer with the given settings. Since no explicit audio config is specified, the default microphone will be used (make sure the audio settings are correct).

# %% [markdown]
# ### Transcribe file to text

# %%
# Replace with the path to your audio file
audio_file = "./TedTalk_Bill_Gates.wav"

# Creates an audio configuration that points to an audio file
audio_config = speechsdk.audio.AudioConfig(filename=audio_file)

# Creates a recognizer with the given settings
speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)

print("Recognizing speech from file...")
result = speech_recognizer.recognize_once()

# Prints the recognized text
print(result.text)
# Out:
# Recognizing speech from file...
# I'm going to talk today about energy and climate, and that might seem a bit surprising because my full time work at the Foundation is mostly about vaccines and seeds, about the things that we need to invent and deliver to help the poorest 2 billion live better lives.

# %%
print(result)
# Out:
# SpeechRecognitionResult(result_id=d17f63f0408c46fd90f3aafe0a5c8ef9, text="I'm going to talk today about energy and climate, and that might seem a bit surprising because my full time work at the Foundation is mostly about vaccines and seeds, about the things that we need to invent and deliver to help the poorest 2 billion live better lives.", reason=ResultReason.RecognizedSpeech)

# %%
def sample_extractive_summarization(result):
    # [START extract_summary]
    import os
    from azure.core.credentials import AzureKeyCredential
    from azure.ai.textanalytics import TextAnalyticsClient

    endpoint = os.environ["AZURE_LANGUAGE_ENDPOINT"]
    key = os.environ["AZURE_LANGUAGE_KEY"]

    text_analytics_client = TextAnalyticsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(key),
    )
    
    document = [result.text]
    poller = text_analytics_client.begin_extract_summary(document)
    extract_summary_results = poller.result()
    for result in extract_summary_results:
        if result.kind == "ExtractiveSummarization":
            print("Summary extracted: \n{}".format(
                " ".join([sentence.text for sentence in result.sentences]))
            )
        elif result.is_error is True:
            print("...Is an error with code '{}' and message '{}'".format(
                result.error.code, result.error.message
            ))
    # [END extract_summary]


if __name__ == "__main__":
    sample_extractive_summarization(result)
# Out:
# Summary extracted:
# I'm going to talk today about energy and climate, and that might seem a bit surprising because my full time work at the Foundation is mostly about vaccines and seeds, about the things that we need to invent and deliver to help the poorest 2 billion live better lives.

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
form_endpoint = os.getenv('form_endpoint')
form_key = os.getenv('form_key')

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient
document_analysis_client = DocumentAnalysisClient(
    endpoint=form_endpoint, credential=AzureKeyCredential(form_key)
)

# %%
model_id = "resumetest"
formUrl = "https://testlanguage1.blob.core.windows.net/testjo12345/New-York-Resume-Template-Creative.pdf?sp=r&st=2024-05-22T16:32:48Z&se=2024-05-23T00:32:48Z&spr=https&sv=2022-11-02&sr=b&sig=ovEfZiq4ewScGL2dewUmDs5DT1O2iuEDlUtVQmsP6g8%3D"

# %%
poller = document_analysis_client.begin_analyze_document_from_url(model_id, formUrl)
result = poller.result()

# %%
for idx, document in enumerate(result.documents):
    print("--------Analyzing document #{}--------".format(idx + 1))
    print("Document has type {}".format(document.doc_type))
    print("Document has confidence {}".format(document.confidence))
    print("Document was analyzed by model with ID {}".format(result.model_id))
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        print("......found field of type '{}' with value '{}' and with confidence {}".format(field.value_type, field_value, field.confidence))
# Out:
# --------Analyzing document #1--------
# Document has type resumetest
# Document has confidence 0.021
# Document was analyzed by model with ID resumetest
# ......found field of type 'string' with value 'ROBERT COOPER' and with confidence 0.826
# ......found field of type 'date' with value '2020-01-01' and with confidence 0.651
# ......found field of type 'string' with value '1515 Pacific Ave Los Angeles, CA 90291 United States' and with confidence 0.247
# ......found field of type 'string' with value 'Security Guard' and with confidence 0.623
# ......found field of type 'string' with value 'S.A.F.E. Approach Level II Training, Hawaii Western College' and with confidence 0.031
# ......found field of type 'string' with value 'email@email.com' and with confidence 0.883
# ......found field of type 'string' with value '3868683442' and with confidence 0.216

# %%
for page in result.pages:
    print("\nLines found on page {}".format(page.page_number))
    for line in page.lines:
        print("...Line '{}'".format(line.content.encode('utf-8')))
    for word in page.words:
        print(
            "...Word '{}' has a confidence of {}".format(
                word.content.encode('utf-8'), word.confidence
            )
        )
    for selection_mark in page.selection_marks:
        print(
            "...Selection mark is '{}' and has a confidence of {}".format(
                selection_mark.state, selection_mark.confidence
            )
        )
# Out:
# Lines found on page 1
# ...Line 'b'ROBERT COOPER''
# ...Line 'b'SECURITY GUARD''
# ...Line 'b'\xc2\xb7 LOS ANGELES, CA 90291, UNITED STATES \xc2\xa2 3868683442''
# ...Line 'b'. DETAILS \xc2\xba''
# ...Line 'b'1515 Pacific Ave''
# ...Line 'b'Los Angeles, CA 90291''
# ...Line 'b'United States''
# ...Line 'b'3868683442''
# ...Line 'b'email@email.com''
# ...Line 'b'Place of birth''
# ...Line 'b'San Antonio''
# ...Line 'b'Driving license''
# ...Line 'b'Full''
# ...Line 'b'O LINKS \xc2\xba''
# ...Line 'b'LinkedIn''
# ...Line 'b'Pinterest''
# ...Line 'b'Resume Templates''
# ...Line 'b'Build this template''
# ...Line 'b'. SKILLS \xc2\xba''
# ...Line 'b'Investigation skills''
# ...Line 'b'Criminal justice knowledge''
# ...Line 'b'Safety compliance''
# ...Line 'b'Restraining devices''
# ...Line 'b'Martial arts/Physical combat''
# ...Line 'b'training''
# ...Line 'b'\xc2\xb7 HOBBIES \xc2\xba''
# ...Line 'b'Running, Mtb, Enduro''
# ...Line 'b'\xc2\xb7 LANGUAGES \xc2\xba''
# ...Line 'b'English''
# ...Line 'b'Spanish''
# ...Line 'b'Italian''
# ...Line 'b'PROFILE''
# ...Line 'b'Safety conscious, attentive Security Guard with eight years experience in protecting and''
# ...Line 'b'guarding VIP individuals in the military and defense sectors. Proficient at observing''
# ...Line 'b'surroundings and immediate settings for possible threats of nonhuman and human nature.''
# ...Line 'b"Presently finishing a bachelor's in criminal justice and qualified as a CPO (Certified"'
# ...Line 'b'Protection Guard).''
# ...Line 'b'EMPLOYMENT HISTORY''
# ...Line 'b'9''
# ...Line 'b'Security Guard at ADT Security, Port Washington''
# ...Line 'b'January 2021 - April 2022''
# ...Line 'b'Responsible for completing reports by recording information, observations, occurrences,''
# ...Line 'b'and surveillance activities, including interviewing of witnesses and acquiring signatures.''
# ...Line 'b'\xc2\xb7 Maintaining environments by monitoring the grounds and equipment controls.''
# ...Line 'b'\xc2\xb7 Logging into security headquarters on the hour during the day and every 2 hours''
# ...Line 'b'with the night shift, notifying control of all in order statuses.''
# ...Line 'b'\xc2\xb7 Utilizing armed force when necessary, to protect company belongings, visitors,''
# ...Line 'b'employees, and clients when needed.''
# ...Line 'b'\xc2\xb7 Apprehending suspects in the event of security breaches and detaining them until''
# ...Line 'b'the police arrive on the scene.''
# ...Line 'b'Security Guard at Copwatch, Jogbani''
# ...Line 'b'January 2020 - April 2022''
# ...Line 'b'Primary purpose is to scan area of grounds for objects/ items that seem out of place and''
# ...Line 'b'notifying Center management of bags or packages that are unattended.''
# ...Line 'b'\xc2\xb7 Inspecting restrooms after closing time for vagrants/ unauthorized personnel.''
# ...Line 'b'\xc2\xb7 Monitoring selected areas via CCTV app on smart devices.''
# ...Line 'b'\xc2\xb7 Ensure flawless equipment operation by finishing preventive maintenance''
# ...Line 'b"necessities, reading the manufacturer's instructions, troubleshooting"'
# ...Line 'b'malfunctions, organizing for repairs if needed, and assessing new equipment and''
# ...Line 'b'techniques''
# ...Line 'b'EDUCATION''
# ...Line 'b'Certified Protection Guard Program (CPOP), International Foundation for Protection''
# ...Line 'b'Guards, Alexandria''
# ...Line 'b'January 2021 - April 2022''
# ...Line 'b'o''
# ...Line 'b'Security Guard Certificate Program (SOCP), ASIS International, North Naples''
# ...Line 'b'April 2022 - April 2022''
# ...Line 'b'\xc2\xb7 Course Curriculum: Law Enforcement Ethics, Foundations in Criminal Law, Report''
# ...Line 'b'Writing, Criminal Profiling, Interviewing Techniques, Crisis Intervention.''
# ...Line 'b'S.A.F.E. Approach Level II Training, Hawaii Western College''
# ...Line 'b'January 2015 - November 2019''
# ...Word 'b'ROBERT'' has a confidence of 0.992
# ...Word 'b'COOPER'' has a confidence of 0.995
# ...Word 'b'SECURITY'' has a confidence of 0.995
# ...Word 'b'GUARD'' has a confidence of 0.995
# ...Word 'b'\xc2\xb7'' has a confidence of 0.506
# ...Word 'b'LOS'' has a confidence of 0.993
# ...Word 'b'ANGELES,'' has a confidence of 0.99
# ...Word 'b'CA'' has a confidence of 0.995
# ...Word 'b'90291,'' has a confidence of 0.991
# ...Word 'b'UNITED'' has a confidence of 0.991
# ...Word 'b'STATES'' has a confidence of 0.973
# ...Word 'b'\xc2\xa2'' has a confidence of 0.506
# ...Word 'b'3868683442'' has a confidence of 0.993
# ...Word 'b'.'' has a confidence of 0.507
# ...Word 'b'DETAILS'' has a confidence of 0.989
# ...Word 'b'\xc2\xba'' has a confidence of 0.509
# ...Word 'b'1515'' has a confidence of 0.993
# ...Word 'b'Pacific'' has a confidence of 0.994
# ...Word 'b'Ave'' has a confidence of 0.993
# ...Word 'b'Los'' has a confidence of 0.993
# ...Word 'b'Angeles,'' has a confidence of 0.993
# ...Word 'b'CA'' has a confidence of 0.996
# ...Word 'b'90291'' has a confidence of 0.993
# ...Word 'b'United'' has a confidence of 0.995
# ...Word 'b'States'' has a confidence of 0.994
# ...Word 'b'3868683442'' has a confidence of 0.994
# ...Word 'b'email@email.com'' has a confidence of 0.964
# ...Word 'b'Place'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'birth'' has a confidence of 0.995
# ...Word 'b'San'' has a confidence of 0.994
# ...Word 'b'Antonio'' has a confidence of 0.995
# ...Word 'b'Driving'' has a confidence of 0.995
# ...Word 'b'license'' has a confidence of 0.994
# ...Word 'b'Full'' has a confidence of 0.992
# ...Word 'b'O'' has a confidence of 0.522
# ...Word 'b'LINKS'' has a confidence of 0.99
# ...Word 'b'\xc2\xba'' has a confidence of 0.505
# ...Word 'b'LinkedIn'' has a confidence of 0.853
# ...Word 'b'Pinterest'' has a confidence of 0.994
# ...Word 'b'Resume'' has a confidence of 0.995
# ...Word 'b'Templates'' has a confidence of 0.994
# ...Word 'b'Build'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'template'' has a confidence of 0.995
# ...Word 'b'.'' has a confidence of 0.51
# ...Word 'b'SKILLS'' has a confidence of 0.993
# ...Word 'b'\xc2\xba'' has a confidence of 0.511
# ...Word 'b'Investigation'' has a confidence of 0.98
# ...Word 'b'skills'' has a confidence of 0.994
# ...Word 'b'Criminal'' has a confidence of 0.995
# ...Word 'b'justice'' has a confidence of 0.994
# ...Word 'b'knowledge'' has a confidence of 0.993
# ...Word 'b'Safety'' has a confidence of 0.995
# ...Word 'b'compliance'' has a confidence of 0.993
# ...Word 'b'Restraining'' has a confidence of 0.993
# ...Word 'b'devices'' has a confidence of 0.994
# ...Word 'b'Martial'' has a confidence of 0.993
# ...Word 'b'arts/Physical'' has a confidence of 0.985
# ...Word 'b'combat'' has a confidence of 0.995
# ...Word 'b'training'' has a confidence of 0.995
# ...Word 'b'\xc2\xb7'' has a confidence of 0.506
# ...Word 'b'HOBBIES'' has a confidence of 0.993
# ...Word 'b'\xc2\xba'' has a confidence of 0.511
# ...Word 'b'Running,'' has a confidence of 0.994
# ...Word 'b'Mtb,'' has a confidence of 0.989
# ...Word 'b'Enduro'' has a confidence of 0.995
# ...Word 'b'\xc2\xb7'' has a confidence of 0.509
# ...Word 'b'LANGUAGES'' has a confidence of 0.979
# ...Word 'b'\xc2\xba'' has a confidence of 0.507
# ...Word 'b'English'' has a confidence of 0.995
# ...Word 'b'Spanish'' has a confidence of 0.995
# ...Word 'b'Italian'' has a confidence of 0.975
# ...Word 'b'PROFILE'' has a confidence of 0.995
# ...Word 'b'Safety'' has a confidence of 0.994
# ...Word 'b'conscious,'' has a confidence of 0.99
# ...Word 'b'attentive'' has a confidence of 0.993
# ...Word 'b'Security'' has a confidence of 0.994
# ...Word 'b'Guard'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'eight'' has a confidence of 0.995
# ...Word 'b'years'' has a confidence of 0.995
# ...Word 'b'experience'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'protecting'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'guarding'' has a confidence of 0.993
# ...Word 'b'VIP'' has a confidence of 0.992
# ...Word 'b'individuals'' has a confidence of 0.991
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'military'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.99
# ...Word 'b'defense'' has a confidence of 0.994
# ...Word 'b'sectors.'' has a confidence of 0.984
# ...Word 'b'Proficient'' has a confidence of 0.993
# ...Word 'b'at'' has a confidence of 0.995
# ...Word 'b'observing'' has a confidence of 0.993
# ...Word 'b'surroundings'' has a confidence of 0.985
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'immediate'' has a confidence of 0.993
# ...Word 'b'settings'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'possible'' has a confidence of 0.993
# ...Word 'b'threats'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'nonhuman'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.991
# ...Word 'b'human'' has a confidence of 0.993
# ...Word 'b'nature.'' has a confidence of 0.989
# ...Word 'b'Presently'' has a confidence of 0.994
# ...Word 'b'finishing'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b"bachelor's"' has a confidence of 0.973
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'criminal'' has a confidence of 0.993
# ...Word 'b'justice'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'qualified'' has a confidence of 0.985
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'CPO'' has a confidence of 0.995
# ...Word 'b'(Certified'' has a confidence of 0.991
# ...Word 'b'Protection'' has a confidence of 0.994
# ...Word 'b'Guard).'' has a confidence of 0.99
# ...Word 'b'EMPLOYMENT'' has a confidence of 0.993
# ...Word 'b'HISTORY'' has a confidence of 0.994
# ...Word 'b'9'' has a confidence of 0.504
# ...Word 'b'Security'' has a confidence of 0.995
# ...Word 'b'Guard'' has a confidence of 0.995
# ...Word 'b'at'' has a confidence of 0.995
# ...Word 'b'ADT'' has a confidence of 0.996
# ...Word 'b'Security,'' has a confidence of 0.991
# ...Word 'b'Port'' has a confidence of 0.993
# ...Word 'b'Washington'' has a confidence of 0.993
# ...Word 'b'January'' has a confidence of 0.995
# ...Word 'b'2021'' has a confidence of 0.992
# ...Word 'b'-'' has a confidence of 0.995
# ...Word 'b'April'' has a confidence of 0.995
# ...Word 'b'2022'' has a confidence of 0.991
# ...Word 'b'Responsible'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'completing'' has a confidence of 0.993
# ...Word 'b'reports'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.996
# ...Word 'b'recording'' has a confidence of 0.994
# ...Word 'b'information,'' has a confidence of 0.977
# ...Word 'b'observations,'' has a confidence of 0.969
# ...Word 'b'occurrences,'' has a confidence of 0.974
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'surveillance'' has a confidence of 0.993
# ...Word 'b'activities,'' has a confidence of 0.982
# ...Word 'b'including'' has a confidence of 0.994
# ...Word 'b'interviewing'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'witnesses'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'acquiring'' has a confidence of 0.993
# ...Word 'b'signatures.'' has a confidence of 0.99
# ...Word 'b'\xc2\xb7'' has a confidence of 0.591
# ...Word 'b'Maintaining'' has a confidence of 0.993
# ...Word 'b'environments'' has a confidence of 0.99
# ...Word 'b'by'' has a confidence of 0.996
# ...Word 'b'monitoring'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'grounds'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'equipment'' has a confidence of 0.962
# ...Word 'b'controls.'' has a confidence of 0.983
# ...Word 'b'\xc2\xb7'' has a confidence of 0.592
# ...Word 'b'Logging'' has a confidence of 0.994
# ...Word 'b'into'' has a confidence of 0.993
# ...Word 'b'security'' has a confidence of 0.994
# ...Word 'b'headquarters'' has a confidence of 0.989
# ...Word 'b'on'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.993
# ...Word 'b'hour'' has a confidence of 0.993
# ...Word 'b'during'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'day'' has a confidence of 0.996
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'every'' has a confidence of 0.948
# ...Word 'b'2'' has a confidence of 0.995
# ...Word 'b'hours'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'night'' has a confidence of 0.995
# ...Word 'b'shift,'' has a confidence of 0.995
# ...Word 'b'notifying'' has a confidence of 0.994
# ...Word 'b'control'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'all'' has a confidence of 0.996
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'order'' has a confidence of 0.995
# ...Word 'b'statuses.'' has a confidence of 0.992
# ...Word 'b'\xc2\xb7'' has a confidence of 0.588
# ...Word 'b'Utilizing'' has a confidence of 0.994
# ...Word 'b'armed'' has a confidence of 0.988
# ...Word 'b'force'' has a confidence of 0.995
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'necessary,'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'protect'' has a confidence of 0.995
# ...Word 'b'company'' has a confidence of 0.995
# ...Word 'b'belongings,'' has a confidence of 0.989
# ...Word 'b'visitors,'' has a confidence of 0.993
# ...Word 'b'employees,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.991
# ...Word 'b'clients'' has a confidence of 0.994
# ...Word 'b'when'' has a confidence of 0.989
# ...Word 'b'needed.'' has a confidence of 0.993
# ...Word 'b'\xc2\xb7'' has a confidence of 0.515
# ...Word 'b'Apprehending'' has a confidence of 0.993
# ...Word 'b'suspects'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.992
# ...Word 'b'event'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'security'' has a confidence of 0.994
# ...Word 'b'breaches'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'detaining'' has a confidence of 0.984
# ...Word 'b'them'' has a confidence of 0.993
# ...Word 'b'until'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'police'' has a confidence of 0.98
# ...Word 'b'arrive'' has a confidence of 0.993
# ...Word 'b'on'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'scene.'' has a confidence of 0.994
# ...Word 'b'Security'' has a confidence of 0.994
# ...Word 'b'Guard'' has a confidence of 0.993
# ...Word 'b'at'' has a confidence of 0.995
# ...Word 'b'Copwatch,'' has a confidence of 0.993
# ...Word 'b'Jogbani'' has a confidence of 0.993
# ...Word 'b'January'' has a confidence of 0.993
# ...Word 'b'2020'' has a confidence of 0.992
# ...Word 'b'-'' has a confidence of 0.948
# ...Word 'b'April'' has a confidence of 0.993
# ...Word 'b'2022'' has a confidence of 0.992
# ...Word 'b'Primary'' has a confidence of 0.994
# ...Word 'b'purpose'' has a confidence of 0.994
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.974
# ...Word 'b'scan'' has a confidence of 0.991
# ...Word 'b'area'' has a confidence of 0.99
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'grounds'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.988
# ...Word 'b'objects/'' has a confidence of 0.983
# ...Word 'b'items'' has a confidence of 0.994
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'seem'' has a confidence of 0.992
# ...Word 'b'out'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'place'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'notifying'' has a confidence of 0.992
# ...Word 'b'Center'' has a confidence of 0.995
# ...Word 'b'management'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'bags'' has a confidence of 0.992
# ...Word 'b'or'' has a confidence of 0.996
# ...Word 'b'packages'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'unattended.'' has a confidence of 0.989
# ...Word 'b'\xc2\xb7'' has a confidence of 0.534
# ...Word 'b'Inspecting'' has a confidence of 0.992
# ...Word 'b'restrooms'' has a confidence of 0.994
# ...Word 'b'after'' has a confidence of 0.995
# ...Word 'b'closing'' has a confidence of 0.994
# ...Word 'b'time'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'vagrants/'' has a confidence of 0.993
# ...Word 'b'unauthorized'' has a confidence of 0.993
# ...Word 'b'personnel.'' has a confidence of 0.985
# ...Word 'b'\xc2\xb7'' has a confidence of 0.626
# ...Word 'b'Monitoring'' has a confidence of 0.993
# ...Word 'b'selected'' has a confidence of 0.993
# ...Word 'b'areas'' has a confidence of 0.995
# ...Word 'b'via'' has a confidence of 0.995
# ...Word 'b'CCTV'' has a confidence of 0.99
# ...Word 'b'app'' has a confidence of 0.996
# ...Word 'b'on'' has a confidence of 0.962
# ...Word 'b'smart'' has a confidence of 0.994
# ...Word 'b'devices.'' has a confidence of 0.993
# ...Word 'b'\xc2\xb7'' has a confidence of 0.533
# ...Word 'b'Ensure'' has a confidence of 0.995
# ...Word 'b'flawless'' has a confidence of 0.994
# ...Word 'b'equipment'' has a confidence of 0.994
# ...Word 'b'operation'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'finishing'' has a confidence of 0.993
# ...Word 'b'preventive'' has a confidence of 0.993
# ...Word 'b'maintenance'' has a confidence of 0.993
# ...Word 'b'necessities,'' has a confidence of 0.989
# ...Word 'b'reading'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b"manufacturer's"' has a confidence of 0.989
# ...Word 'b'instructions,'' has a confidence of 0.985
# ...Word 'b'troubleshooting'' has a confidence of 0.988
# ...Word 'b'malfunctions,'' has a confidence of 0.993
# ...Word 'b'organizing'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.997
# ...Word 'b'repairs'' has a confidence of 0.995
# ...Word 'b'if'' has a confidence of 0.993
# ...Word 'b'needed,'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'assessing'' has a confidence of 0.994
# ...Word 'b'new'' has a confidence of 0.997
# ...Word 'b'equipment'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'techniques'' has a confidence of 0.981
# ...Word 'b'EDUCATION'' has a confidence of 0.993
# ...Word 'b'Certified'' has a confidence of 0.993
# ...Word 'b'Protection'' has a confidence of 0.984
# ...Word 'b'Guard'' has a confidence of 0.995
# ...Word 'b'Program'' has a confidence of 0.994
# ...Word 'b'(CPOP),'' has a confidence of 0.993
# ...Word 'b'International'' has a confidence of 0.975
# ...Word 'b'Foundation'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'Protection'' has a confidence of 0.993
# ...Word 'b'Guards,'' has a confidence of 0.994
# ...Word 'b'Alexandria'' has a confidence of 0.993
# ...Word 'b'January'' has a confidence of 0.995
# ...Word 'b'2021'' has a confidence of 0.992
# ...Word 'b'-'' has a confidence of 0.995
# ...Word 'b'April'' has a confidence of 0.995
# ...Word 'b'2022'' has a confidence of 0.992
# ...Word 'b'o'' has a confidence of 0.59
# ...Word 'b'Security'' has a confidence of 0.993
# ...Word 'b'Guard'' has a confidence of 0.995
# ...Word 'b'Certificate'' has a confidence of 0.993
# ...Word 'b'Program'' has a confidence of 0.993
# ...Word 'b'(SOCP),'' has a confidence of 0.993
# ...Word 'b'ASIS'' has a confidence of 0.988
# ...Word 'b'International,'' has a confidence of 0.97
# ...Word 'b'North'' has a confidence of 0.995
# ...Word 'b'Naples'' has a confidence of 0.994
# ...Word 'b'April'' has a confidence of 0.995
# ...Word 'b'2022'' has a confidence of 0.991
# ...Word 'b'-'' has a confidence of 0.927
# ...Word 'b'April'' has a confidence of 0.995
# ...Word 'b'2022'' has a confidence of 0.992
# ...Word 'b'\xc2\xb7'' has a confidence of 0.596
# ...Word 'b'Course'' has a confidence of 0.994
# ...Word 'b'Curriculum:'' has a confidence of 0.972
# ...Word 'b'Law'' has a confidence of 0.992
# ...Word 'b'Enforcement'' has a confidence of 0.989
# ...Word 'b'Ethics,'' has a confidence of 0.993
# ...Word 'b'Foundations'' has a confidence of 0.99
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'Criminal'' has a confidence of 0.991
# ...Word 'b'Law,'' has a confidence of 0.991
# ...Word 'b'Report'' has a confidence of 0.994
# ...Word 'b'Writing,'' has a confidence of 0.994
# ...Word 'b'Criminal'' has a confidence of 0.994
# ...Word 'b'Profiling,'' has a confidence of 0.991
# ...Word 'b'Interviewing'' has a confidence of 0.986
# ...Word 'b'Techniques,'' has a confidence of 0.988
# ...Word 'b'Crisis'' has a confidence of 0.994
# ...Word 'b'Intervention.'' has a confidence of 0.981
# ...Word 'b'S.A.F.E.'' has a confidence of 0.993
# ...Word 'b'Approach'' has a confidence of 0.995
# ...Word 'b'Level'' has a confidence of 0.995
# ...Word 'b'II'' has a confidence of 0.709
# ...Word 'b'Training,'' has a confidence of 0.995
# ...Word 'b'Hawaii'' has a confidence of 0.995
# ...Word 'b'Western'' has a confidence of 0.995
# ...Word 'b'College'' has a confidence of 0.995
# ...Word 'b'January'' has a confidence of 0.995
# ...Word 'b'2015'' has a confidence of 0.992
# ...Word 'b'-'' has a confidence of 0.989
# ...Word 'b'November'' has a confidence of 0.961
# ...Word 'b'2019'' has a confidence of 0.993
# ...Selection mark is 'selected' and has a confidence of 0.1
#
# Lines found on page 2
# ...Line 'b'ACHIEVEMENTS''
# ...Line 'b'O-''
# ...Line 'b'. Decreased theft of hotel items like linen, towels, d\xc3\xa9cor pieces, and cutlery by 73%''
# ...Line 'b'by improving vigilance strategies, particularly for guests leaving the hotel.''
# ...Line 'b'\xc2\xb7 Enhancing detection/monitoring procedures by having 15 360 degrees CCTV''
# ...Line 'b'cameras installed at the back of shopping aisles and in storerooms, which cut''
# ...Line 'b'product stock theft by 93%.''
# ...Line 'b'\xc2\xb7 Introduced inventive loss prevention techniques by installing an X-ray scanning''
# ...Line 'b'system at every entrance and exit in the building, which reduced theft by 28%.''
# ...Line 'b'\xc2\xb7 Improved access control, which reduced unauthorized entry and solicitation by''
# ...Line 'b'26% using an announcement notification app, where visitors may be admitted/''
# ...Line 'b"declined entry straight from the employee's smart device."'
# ...Word 'b'ACHIEVEMENTS'' has a confidence of 0.988
# ...Word 'b'O-'' has a confidence of 0.555
# ...Word 'b'.'' has a confidence of 0.595
# ...Word 'b'Decreased'' has a confidence of 0.993
# ...Word 'b'theft'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'hotel'' has a confidence of 0.995
# ...Word 'b'items'' has a confidence of 0.992
# ...Word 'b'like'' has a confidence of 0.992
# ...Word 'b'linen,'' has a confidence of 0.991
# ...Word 'b'towels,'' has a confidence of 0.972
# ...Word 'b'd\xc3\xa9cor'' has a confidence of 0.548
# ...Word 'b'pieces,'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.962
# ...Word 'b'cutlery'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'73%'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'improving'' has a confidence of 0.991
# ...Word 'b'vigilance'' has a confidence of 0.993
# ...Word 'b'strategies,'' has a confidence of 0.993
# ...Word 'b'particularly'' has a confidence of 0.981
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'guests'' has a confidence of 0.994
# ...Word 'b'leaving'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'hotel.'' has a confidence of 0.993
# ...Word 'b'\xc2\xb7'' has a confidence of 0.609
# ...Word 'b'Enhancing'' has a confidence of 0.994
# ...Word 'b'detection/monitoring'' has a confidence of 0.981
# ...Word 'b'procedures'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.994
# ...Word 'b'having'' has a confidence of 0.99
# ...Word 'b'15'' has a confidence of 0.995
# ...Word 'b'360'' has a confidence of 0.995
# ...Word 'b'degrees'' has a confidence of 0.993
# ...Word 'b'CCTV'' has a confidence of 0.989
# ...Word 'b'cameras'' has a confidence of 0.994
# ...Word 'b'installed'' has a confidence of 0.994
# ...Word 'b'at'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'back'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'shopping'' has a confidence of 0.995
# ...Word 'b'aisles'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.98
# ...Word 'b'storerooms,'' has a confidence of 0.988
# ...Word 'b'which'' has a confidence of 0.994
# ...Word 'b'cut'' has a confidence of 0.995
# ...Word 'b'product'' has a confidence of 0.994
# ...Word 'b'stock'' has a confidence of 0.995
# ...Word 'b'theft'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.996
# ...Word 'b'93%.'' has a confidence of 0.979
# ...Word 'b'\xc2\xb7'' has a confidence of 0.536
# ...Word 'b'Introduced'' has a confidence of 0.982
# ...Word 'b'inventive'' has a confidence of 0.993
# ...Word 'b'loss'' has a confidence of 0.992
# ...Word 'b'prevention'' has a confidence of 0.993
# ...Word 'b'techniques'' has a confidence of 0.983
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'installing'' has a confidence of 0.991
# ...Word 'b'an'' has a confidence of 0.995
# ...Word 'b'X-ray'' has a confidence of 0.993
# ...Word 'b'scanning'' has a confidence of 0.994
# ...Word 'b'system'' has a confidence of 0.994
# ...Word 'b'at'' has a confidence of 0.996
# ...Word 'b'every'' has a confidence of 0.995
# ...Word 'b'entrance'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'exit'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'building,'' has a confidence of 0.991
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'reduced'' has a confidence of 0.994
# ...Word 'b'theft'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.993
# ...Word 'b'28%.'' has a confidence of 0.973
# ...Word 'b'\xc2\xb7'' has a confidence of 0.536
# ...Word 'b'Improved'' has a confidence of 0.991
# ...Word 'b'access'' has a confidence of 0.995
# ...Word 'b'control,'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'reduced'' has a confidence of 0.993
# ...Word 'b'unauthorized'' has a confidence of 0.983
# ...Word 'b'entry'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'solicitation'' has a confidence of 0.99
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'26%'' has a confidence of 0.995
# ...Word 'b'using'' has a confidence of 0.995
# ...Word 'b'an'' has a confidence of 0.997
# ...Word 'b'announcement'' has a confidence of 0.99
# ...Word 'b'notification'' has a confidence of 0.992
# ...Word 'b'app,'' has a confidence of 0.992
# ...Word 'b'where'' has a confidence of 0.994
# ...Word 'b'visitors'' has a confidence of 0.993
# ...Word 'b'may'' has a confidence of 0.996
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'admitted/'' has a confidence of 0.992
# ...Word 'b'declined'' has a confidence of 0.995
# ...Word 'b'entry'' has a confidence of 0.995
# ...Word 'b'straight'' has a confidence of 0.994
# ...Word 'b'from'' has a confidence of 0.992
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b"employee's"' has a confidence of 0.995
# ...Word 'b'smart'' has a confidence of 0.995
# ...Word 'b'device.'' has a confidence of 0.994

# %%
for i, table in enumerate(result.tables):
    print("\nTable {} can be found on page:".format(i + 1))
    for region in table.bounding_regions:
        print("...{}".format(i + 1, region.page_number))
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
                cell.row_index, cell.column_index, cell.content.encode('utf-8')
            )
        )
print("-----------------------------------")
# Out:
# -----------------------------------
